# %%
import pandas as pd
df=pd.read_csv('weatherHistory.csv')
df[2:10:2]
# Out:
#                   Formatted Date        Summary Precip Type  Temperature  \
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain     9.377778
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain     8.755556
# 6  2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain     7.733333
# 8  2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain    10.822222
#
#    Apparent Temperature  Humidity  Wind Speed  Wind Bearing  Visibilit  \
# 2              9.377778      0.89      3.9284         204.0    14.9569
# 4              6.977778      0.83     11.0446         259.0    15.8263
# 6              5.522222      0.95     12.3648         259.0     9.9820
# 8             10.822222      0.82     11.3183         259.0     9.9820
#
#    Loud Cover  Pressure                      Daily Summary
# 2         0.0   1015.94  Partly cloudy throughout the day.
# 4         0.0   1016.51  Partly cloudy throughout the day.
# 6         0.0   1016.72  Partly cloudy throughout the day.
# ...

# %%
df['Temperature'].head(10).max()
# Out:
# 13.77222222222222

# %%
df['Formatted Date'].head(10)[df['Wind Bearing']>200]
# Out:
# 0    2006-04-01 00:00:00.000 +0200
# 1    2006-04-01 01:00:00.000 +0200
# 2    2006-04-01 02:00:00.000 +0200
# 3    2006-04-01 03:00:00.000 +0200
# 4    2006-04-01 04:00:00.000 +0200
# 5    2006-04-01 05:00:00.000 +0200
# 6    2006-04-01 06:00:00.000 +0200
# 7    2006-04-01 07:00:00.000 +0200
# 8    2006-04-01 08:00:00.000 +0200
# 9    2006-04-01 09:00:00.000 +0200
# Name: Formatted Date, dtype: object

# %%
df['Temperature'].head(10).mean()
# Out:
# 9.557222222222222

# %%
type(df['Temperature'])
# Out:
# pandas.core.series.Series

# %%
df.describe()
# Out:
#         Temperature  Apparent Temperature      Humidity    Wind Speed  \
# count  96453.000000          96453.000000  96453.000000  96453.000000
# mean      11.932678             10.855029      0.734899     10.810640
# std        9.551546             10.696847      0.195473      6.913571
# min      -21.822222            -27.716667      0.000000      0.000000
# 25%        4.688889              2.311111      0.600000      5.828200
# 50%       12.000000             12.000000      0.780000      9.965900
# 75%       18.838889             18.838889      0.890000     14.135800
# max       39.905556             39.344444      1.000000     63.852600
#
#        Wind Bearing     Visibilit  Loud Cover      Pressure
# count  96453.000000  96453.000000     96453.0  96453.000000
# mean     187.509232     10.347325         0.0   1003.235956
# std      107.383428      4.192123         0.0    116.969906
# min        0.000000      0.000000         0.0      0.000000
# ...

# %%
df[df.Temperature>=38.90]
# Out:
#                       Formatted Date        Summary Precip Type  Temperature  \
# 12664  2007-07-19 16:00:00.000 +0200  Partly Cloudy        rain    38.983333
# 12711  2007-07-20 15:00:00.000 +0200  Partly Cloudy        rain    38.983333
# 12712  2007-07-20 16:00:00.000 +0200  Partly Cloudy        rain    38.983333
# 12737  2007-07-21 17:00:00.000 +0200  Partly Cloudy        rain    39.588889
# 12759  2007-07-22 15:00:00.000 +0200          Clear        rain    39.905556
#
#        Apparent Temperature  Humidity  Wind Speed  Wind Bearing  Visibilit  \
# 12664             37.461111      0.18      8.9355         175.0     9.9820
# 12711             36.627778      0.14     12.7190         167.0     9.9820
# 12712             36.800000      0.15     15.4077         133.0     9.9820
# 12737             37.600000      0.15     12.2038         283.0    10.3523
# 12759             37.538889      0.13     23.5865         250.0     9.9820
#
# ...

# %%
df[df.Temperature==df.Temperature.max()]
# Out:
#                       Formatted Date Summary Precip Type  Temperature  \
# 12759  2007-07-22 15:00:00.000 +0200   Clear        rain    39.905556
#
#        Apparent Temperature  Humidity  Wind Speed  Wind Bearing  Visibilit  \
# 12759             37.538889      0.13     23.5865         250.0      9.982
#
#        Loud Cover  Pressure                             Daily Summary
# 12759         0.0   1007.55  Partly cloudy starting in the afternoon.

# %%
df[['Formatted Date','Daily Summary','Temperature']][df.Temperature>=38.90]
# Out:
#                       Formatted Date  \
# 12664  2007-07-19 16:00:00.000 +0200
# 12711  2007-07-20 15:00:00.000 +0200
# 12712  2007-07-20 16:00:00.000 +0200
# 12737  2007-07-21 17:00:00.000 +0200
# 12759  2007-07-22 15:00:00.000 +0200
#
#                                            Daily Summary  Temperature
# 12664           Partly cloudy starting in the afternoon.    38.983333
# 12711  Partly cloudy starting in the afternoon contin...    38.983333
# 12712  Partly cloudy starting in the afternoon contin...    38.983333
# 12737  Partly cloudy starting in the morning continui...    39.588889
# 12759           Partly cloudy starting in the afternoon.    39.905556

# %%
df.set_index('Temperature',inplace=True)

# %%
df
# Out:
#                             Formatted Date        Summary Precip Type  \
# Temperature
# 9.472222     2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 9.355556     2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 9.377778     2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 8.288889     2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 8.755556     2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                                    ...            ...         ...
# 26.016667    2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 24.583333    2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 22.038889    2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 21.522222    2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 20.438889    2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#              Apparent Temperature  Humidity  Wind Speed  Wind Bearing  \
# Temperature
# ...

# %%
df.loc[22]
# Out:
#                             Formatted Date                   Summary  \
# Temperature
# 22.0         2006-09-27 12:00:00.000 +0200             Mostly Cloudy
# 22.0         2007-08-11 09:00:00.000 +0200             Mostly Cloudy
# 22.0         2007-07-24 04:00:00.000 +0200                     Clear
# 22.0         2007-05-05 11:00:00.000 +0200             Partly Cloudy
# 22.0         2008-07-20 08:00:00.000 +0200                     Clear
# 22.0         2008-06-09 09:00:00.000 +0200             Partly Cloudy
# 22.0         2009-04-18 14:00:00.000 +0200             Mostly Cloudy
# 22.0         2009-04-04 14:00:00.000 +0200             Partly Cloudy
# 22.0         2010-07-10 08:00:00.000 +0200             Partly Cloudy
# 22.0         2010-07-15 06:00:00.000 +0200                     Clear
# 22.0         2010-06-13 06:00:00.000 +0200                     Clear
# 22.0         2011-06-05 07:00:00.000 +0200             Mostly Cloudy
# ...

# %%
df.reset_index(inplace=True)

# %%
df[2:10]
# Out:
#    Temperature                 Formatted Date        Summary Precip Type  \
# 2     9.377778  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3     8.288889  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4     8.755556  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# 5     9.222222  2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain
# 6     7.733333  2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain
# 7     8.772222  2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain
# 8    10.822222  2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain
# 9    13.772222  2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain
#
#    Apparent Temperature  Humidity  Wind Speed  Wind Bearing  Visibilit  \
# 2              9.377778      0.89      3.9284         204.0    14.9569
# 3              5.944444      0.83     14.1036         269.0    15.8263
# 4              6.977778      0.83     11.0446         259.0    15.8263
# ...
